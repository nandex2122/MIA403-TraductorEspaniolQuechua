# %% [markdown]
# ## BART

# %%
pip uninstall keras tensorflow -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping keras as it is not installed.
# WARNING: Skipping tensorflow as it is not installed.

# %%
pip install accelerate --upgrade
# Out:
# Collecting accelerate
#   Using cached accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading numpy-2.3.4-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: pyyaml in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from accelerate) (6.0.2)
# Collecting torch>=2.0.0 (from accelerate)
#   Downloading torch-2.9.0-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Collecting huggingface_hub>=0.21.0 (from accelerate)
#   Using cached huggingface_hub-0.35.3-py3-none-any.whl.metadata (14 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl.metadata (4.1 kB)
# Collecting filelock (from huggingface_hub>=0.21.0->accelerate)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub>=0.21.0->accelerate)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.5)
# Collecting tqdm>=4.42.1 (from huggingface_hub>=0.21.0->accelerate)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Collecting sympy>=1.13.3 (from torch>=2.0.0->accelerate)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=2.0.0->accelerate)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch>=2.0.0->accelerate) (80.9.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.0.0->accelerate)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from tqdm>=4.42.1->huggingface_hub>=0.21.0->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2025.10.5)
# Using cached accelerate-1.10.1-py3-none-any.whl (374 kB)
# Downloading numpy-2.3.4-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 12.8/12.8 MB 67.2 MB/s  0:00:00
# Using cached huggingface_hub-0.35.3-py3-none-any.whl (564 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl (320 kB)
# Downloading torch-2.9.0-cp313-cp313-win_amd64.whl (109.3 MB)
#    ---------------------------------------- 0.0/109.3 MB ? eta -:--:--
#    -------- ------------------------------ 23.9/109.3 MB 117.8 MB/s eta 0:00:01
#    ----------------- --------------------- 49.3/109.3 MB 117.4 MB/s eta 0:00:01
#    -------------------------- ------------ 73.1/109.3 MB 117.2 MB/s eta 0:00:01
#    ---------------------------------- ---- 97.0/109.3 MB 117.1 MB/s eta 0:00:01
#    -------------------------------------  109.1/109.3 MB 116.3 MB/s eta 0:00:01
#    ---------------------------------------- 109.3/109.3 MB 99.9 MB/s  0:00:01
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Installing collected packages: mpmath, tqdm, sympy, safetensors, numpy, networkx, fsspec, filelock, torch, huggingface_hub, accelerate
#
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    ----------------------------------------  0/11 [mpmath]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    --- ------------------------------------  1/11 [tqdm]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ---------- -----------------------------  3/11 [safetensors]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    ------------------ ---------------------  5/11 [networkx]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    ------------------------- --------------  7/11 [filelock]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    ----------------------------- ----------  8/11 [torch]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    -------------------------------- -------  9/11 [huggingface_hub]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ------------------------------------ --- 10/11 [accelerate]
#    ---------------------------------------- 11/11 [accelerate]
#
# Successfully installed accelerate-1.10.1 filelock-3.20.0 fsspec-2025.9.0 huggingface_hub-0.35.3 mpmath-1.3.0 networkx-3.5 numpy-2.3.4 safetensors-0.6.2 sympy-1.14.0 torch-2.9.0 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade "accelerate>=0.26.0"
# Out:
# Requirement already satisfied: accelerate>=0.26.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (1.10.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from accelerate>=0.26.0) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from accelerate>=0.26.0) (25.0)
# Requirement already satisfied: psutil in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from accelerate>=0.26.0) (7.0.0)
# Requirement already satisfied: pyyaml in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from accelerate>=0.26.0) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from accelerate>=0.26.0) (2.9.0)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from accelerate>=0.26.0) (0.35.3)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from accelerate>=0.26.0) (0.6.2)
# Requirement already satisfied: filelock in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (2025.9.0)
# Requirement already satisfied: requests in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch>=2.0.0->accelerate>=0.26.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch>=2.0.0->accelerate>=0.26.0) (3.5)
# Requirement already satisfied: jinja2 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch>=2.0.0->accelerate>=0.26.0) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch>=2.0.0->accelerate>=0.26.0) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=0.26.0) (1.3.0)
# Requirement already satisfied: colorama in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from tqdm>=4.42.1->huggingface_hub>=0.21.0->accelerate>=0.26.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from jinja2->torch>=2.0.0->accelerate>=0.26.0) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (2025.10.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (2.9.0)
# Requirement already satisfied: filelock in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade transformers
# Out:
# Collecting transformers
#   Using cached transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from transformers) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2025.9.18-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: colorama in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests->transformers) (2025.10.5)
# Using cached transformers-4.57.1-py3-none-any.whl (12.0 MB)
# Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
# Downloading regex-2025.9.18-cp313-cp313-win_amd64.whl (275 kB)
# Installing collected packages: regex, tokenizers, transformers
#
#    ---------------------------------------- 0/3 [regex]
#    ------------- -------------------------- 1/3 [tokenizers]
#    ------------- -------------------------- 1/3 [tokenizers]
#    ------------- -------------------------- 1/3 [tokenizers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    ---------------------------------------- 3/3 [transformers]
#
# Successfully installed regex-2025.9.18 tokenizers-0.22.1 transformers-4.57.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-4.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: filelock in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from datasets) (2.3.4)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-21.0.0-cp313-cp313-win_amd64.whl.metadata (3.4 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: requests>=2.32.2 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2025.9.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from datasets) (0.35.3)
# Requirement already satisfied: packaging in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from datasets) (6.0.2)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.13.0-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: anyio in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from httpx<1.0.0->datasets) (4.10.0)
# Requirement already satisfied: certifi in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (24.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading multidict-6.7.0-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets)
#   Downloading yarl-1.22.0-cp313-cp313-win_amd64.whl.metadata (77 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: colorama in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-4.2.0-py3-none-any.whl (506 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading aiohttp-3.13.0-cp313-cp313-win_amd64.whl (450 kB)
# Downloading multidict-6.7.0-cp313-cp313-win_amd64.whl (45 kB)
# Downloading yarl-1.22.0-cp313-cp313-win_amd64.whl (86 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl (40 kB)
# Downloading pyarrow-21.0.0-cp313-cp313-win_amd64.whl (26.1 MB)
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ------------------------------- -------- 20.4/26.1 MB 97.2 MB/s eta 0:00:01
#    ---------------------------------------- 26.1/26.1 MB 85.5 MB/s  0:00:00
# Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 11.0/11.0 MB 100.0 MB/s  0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl (31 kB)
# Installing collected packages: pytz, xxhash, tzdata, pyarrow, propcache, multidict, frozenlist, dill, aiohappyeyeballs, yarl, pandas, multiprocess, aiosignal, aiohttp, datasets
#
#    ----------------------------------------  0/15 [pytz]
#    ----------------------------------------  0/15 [pytz]
#    -- -------------------------------------  1/15 [xxhash]
#    ----- ----------------------------------  2/15 [tzdata]
#    ----- ----------------------------------  2/15 [tzdata]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    -------- -------------------------------  3/15 [pyarrow]
#    ------------- --------------------------  5/15 [multidict]
#    ---------------- -----------------------  6/15 [frozenlist]
#    ------------------ ---------------------  7/15 [dill]
#    ------------------ ---------------------  7/15 [dill]
#    ------------------ ---------------------  7/15 [dill]
#    ------------------ ---------------------  7/15 [dill]
#    ------------------ ---------------------  7/15 [dill]
#    ------------------ ---------------------  7/15 [dill]
#    ------------------ ---------------------  7/15 [dill]
#    ------------------ ---------------------  7/15 [dill]
#    ------------------ ---------------------  7/15 [dill]
#    ------------------------ ---------------  9/15 [yarl]
#    ------------------------ ---------------  9/15 [yarl]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    ----------------------------- ---------- 11/15 [multiprocess]
#    ----------------------------- ---------- 11/15 [multiprocess]
#    ----------------------------- ---------- 11/15 [multiprocess]
#    ----------------------------- ---------- 11/15 [multiprocess]
#    ----------------------------- ---------- 11/15 [multiprocess]
#    ----------------------------- ---------- 11/15 [multiprocess]
#    ----------------------------- ---------- 11/15 [multiprocess]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ---------------------------------- ----- 13/15 [aiohttp]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ------------------------------------- -- 14/15 [datasets]
#    ---------------------------------------- 15/15 [datasets]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.0 aiosignal-1.4.0 datasets-4.2.0 dill-0.4.0 frozenlist-1.8.0 multidict-6.7.0 multiprocess-0.70.16 pandas-2.3.3 propcache-0.4.1 pyarrow-21.0.0 pytz-2025.2 tzdata-2025.2 xxhash-3.6.0 yarl-1.22.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Paso 1: Convertir corpus a CSV para entrenamiento

# %%
import zipfile
import os

ruta_zip = '01_corpus_total.zip'           # Ruta del archivo zip
carpeta_destino = './'  # Carpeta donde quieres extraer el contenido

# Crear la carpeta destino si no existe
os.makedirs(carpeta_destino, exist_ok=True)

# Abrir el archivo zip y extraer todo
with zipfile.ZipFile(ruta_zip, 'r') as zip_ref:
    zip_ref.extractall(carpeta_destino)

print(f'Contenido extraído en {carpeta_destino}')
# Out:
# Contenido extraído en ./

# %%
import re

archivo_original = 'corpus_total_combinado.txt'
archivo_salida = 'corpus_total_formateado.txt'

with open(archivo_original, 'r', encoding='utf-8') as f_in, \
     open(archivo_salida, 'w', encoding='utf-8') as f_out:

    for linea in f_in:
        linea = linea.strip()
        # Buscar los dos IDs y textos intermedios con regex
        # Patrón: ID (6 dígitos) + texto + ID (6 dígitos) + texto
        match = re.match(r'^(\d{6})\s(.+)\s(\d{6})\s(.+)$', linea)
        if match:
            id_esp = match.group(1)
            texto_esp = match.group(2)
            id_que = match.group(3)
            texto_que = match.group(4)

            # Escribir con tabuladores
            f_out.write(f"{id_esp}\t{texto_esp}\t{id_que}\t{texto_que}\n")
        else:
            print(f"Línea no coincide con el patrón esperado:\n{linea}")

print("Archivo formateado guardado en", archivo_salida)
# Out:
# Línea no coincide con el patrón esperado:
# 001183		001183	Dispinsaykuway
# Línea no coincide con el patrón esperado:
# 001519		001519	Morguemanmi wañuqta apasaqku
# Archivo formateado guardado en corpus_total_formateado.txt

# %%
import csv
import os
os.environ["TRANSFORMERS_NO_TF"] = "1"

# Ruta de Archivo
carpeta = "./"
os.makedirs(carpeta, exist_ok=True)

#nombre_archivo = "esp_ingles - 2024-11-02.txt"
nombre_archivo = "corpus_total_formateado.txt"
nombre_corpus = "corpus_trad.csv"

path_1 = os.path.join(carpeta, nombre_archivo)
path_2 = os.path.join(carpeta, nombre_corpus)

with open(nombre_archivo, "r", encoding="utf-8") as infile, \
     open(nombre_corpus, "w", newline='', encoding="utf-8") as outfile:

    writer = csv.writer(outfile)
    writer.writerow(["source", "target"])  # encabezado

    for line in infile:
        parts = line.strip().split("\t")
        if len(parts) == 4:
            _, source, _, target = parts
            writer.writerow([source, target])

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (2.9.0)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.22.1%2Bcu118-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.7.1%2Bcu118-cp313-cp313-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: filelock in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from torchvision) (2.3.4)
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.7.1%2Bcu118-cp313-cp313-win_amd64.whl.metadata (27 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading https://download.pytorch.org/whl/pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ferhe\.conda\envs\proytesis2\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/cu118/torchvision-0.22.1%2Bcu118-cp313-cp313-win_amd64.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 5.5/5.5 MB 58.1 MB/s  0:00:00
# Downloading https://download.pytorch.org/whl/cu118/torch-2.7.1%2Bcu118-cp313-cp313-win_amd64.whl (2817.2 MB)
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB 114.0 MB/s eta 0:00:25
#     --------------------------------------- 0.0/2.8 GB 110.9 MB/s eta 0:00:25
#     --------------------------------------- 0.1/2.8 GB 111.6 MB/s eta 0:00:25
#    - -------------------------------------- 0.1/2.8 GB 110.2 MB/s eta 0:00:25
#    - -------------------------------------- 0.1/2.8 GB 109.9 MB/s eta 0:00:25
#    - -------------------------------------- 0.1/2.8 GB 110.2 MB/s eta 0:00:25
#    -- ------------------------------------- 0.2/2.8 GB 110.0 MB/s eta 0:00:25
#    -- ------------------------------------- 0.2/2.8 GB 109.4 MB/s eta 0:00:25
#    -- ------------------------------------- 0.2/2.8 GB 109.4 MB/s eta 0:00:24
#    --- ------------------------------------ 0.2/2.8 GB 109.3 MB/s eta 0:00:24
#    --- ------------------------------------ 0.3/2.8 GB 109.2 MB/s eta 0:00:24
#    --- ------------------------------------ 0.3/2.8 GB 108.4 MB/s eta 0:00:24
#    ---- ----------------------------------- 0.3/2.8 GB 107.8 MB/s eta 0:00:24
#    ---- ----------------------------------- 0.3/2.8 GB 108.4 MB/s eta 0:00:24
#    ---- ----------------------------------- 0.3/2.8 GB 107.7 MB/s eta 0:00:24
#    ----- ---------------------------------- 0.4/2.8 GB 108.1 MB/s eta 0:00:23
#    ----- ---------------------------------- 0.4/2.8 GB 107.9 MB/s eta 0:00:23
#    ----- ---------------------------------- 0.4/2.8 GB 107.7 MB/s eta 0:00:23
#    ------ --------------------------------- 0.4/2.8 GB 107.8 MB/s eta 0:00:23
#    ------ --------------------------------- 0.5/2.8 GB 107.8 MB/s eta 0:00:22
#    ------ --------------------------------- 0.5/2.8 GB 107.4 MB/s eta 0:00:22
#    ------- -------------------------------- 0.5/2.8 GB 107.9 MB/s eta 0:00:22
#    ------- -------------------------------- 0.5/2.8 GB 106.4 MB/s eta 0:00:22
#    ------- -------------------------------- 0.5/2.8 GB 106.7 MB/s eta 0:00:22
#    ------- -------------------------------- 0.6/2.8 GB 106.8 MB/s eta 0:00:22
#    -------- ------------------------------- 0.6/2.8 GB 106.9 MB/s eta 0:00:21
#    -------- ------------------------------- 0.6/2.8 GB 106.5 MB/s eta 0:00:21
#    -------- ------------------------------- 0.6/2.8 GB 106.7 MB/s eta 0:00:21
#    --------- ------------------------------ 0.6/2.8 GB 106.1 MB/s eta 0:00:21
#    --------- ------------------------------ 0.7/2.8 GB 106.8 MB/s eta 0:00:21
#    --------- ------------------------------ 0.7/2.8 GB 106.3 MB/s eta 0:00:21
#    ---------- ----------------------------- 0.7/2.8 GB 106.4 MB/s eta 0:00:20
#    ---------- ----------------------------- 0.7/2.8 GB 107.0 MB/s eta 0:00:20
#    ---------- ----------------------------- 0.8/2.8 GB 106.9 MB/s eta 0:00:20
#    ----------- ---------------------------- 0.8/2.8 GB 108.4 MB/s eta 0:00:19
#    ----------- ---------------------------- 0.8/2.8 GB 108.0 MB/s eta 0:00:19
#    ----------- ---------------------------- 0.8/2.8 GB 108.2 MB/s eta 0:00:19
#    ------------ --------------------------- 0.9/2.8 GB 108.4 MB/s eta 0:00:19
#    ------------ --------------------------- 0.9/2.8 GB 109.0 MB/s eta 0:00:18
#    ------------ --------------------------- 0.9/2.8 GB 108.3 MB/s eta 0:00:18
#    ------------ --------------------------- 0.9/2.8 GB 108.4 MB/s eta 0:00:18
#    ------------- -------------------------- 0.9/2.8 GB 99.7 MB/s eta 0:00:20
#    ------------- -------------------------- 0.9/2.8 GB 99.1 MB/s eta 0:00:19
#    ------------- -------------------------- 1.0/2.8 GB 99.5 MB/s eta 0:00:19
#    ------------- -------------------------- 1.0/2.8 GB 99.1 MB/s eta 0:00:19
#    -------------- ------------------------- 1.0/2.8 GB 99.3 MB/s eta 0:00:19
#    -------------- ------------------------- 1.0/2.8 GB 98.9 MB/s eta 0:00:19
#    -------------- ------------------------- 1.0/2.8 GB 99.2 MB/s eta 0:00:18
#    --------------- ------------------------ 1.1/2.8 GB 98.9 MB/s eta 0:00:18
#    --------------- ------------------------ 1.1/2.8 GB 98.7 MB/s eta 0:00:18
#    --------------- ------------------------ 1.1/2.8 GB 98.8 MB/s eta 0:00:18
#    ---------------- ----------------------- 1.1/2.8 GB 98.1 MB/s eta 0:00:18
#    ---------------- ----------------------- 1.2/2.8 GB 98.9 MB/s eta 0:00:17
#    ---------------- ----------------------- 1.2/2.8 GB 107.5 MB/s eta 0:00:16
#    ----------------- ---------------------- 1.2/2.8 GB 107.5 MB/s eta 0:00:16
#    ----------------- ---------------------- 1.2/2.8 GB 107.5 MB/s eta 0:00:15
#    ----------------- ---------------------- 1.2/2.8 GB 107.5 MB/s eta 0:00:15
#    ------------------ --------------------- 1.3/2.8 GB 107.6 MB/s eta 0:00:15
#    ------------------ --------------------- 1.3/2.8 GB 108.1 MB/s eta 0:00:15
#    ------------------ --------------------- 1.3/2.8 GB 107.5 MB/s eta 0:00:14
#    ------------------ --------------------- 1.3/2.8 GB 107.2 MB/s eta 0:00:14
#    ------------------- -------------------- 1.4/2.8 GB 108.0 MB/s eta 0:00:14
#    ------------------- -------------------- 1.4/2.8 GB 108.0 MB/s eta 0:00:14
#    ------------------- -------------------- 1.4/2.8 GB 108.0 MB/s eta 0:00:14
#    -------------------- ------------------- 1.4/2.8 GB 108.0 MB/s eta 0:00:13
#    -------------------- ------------------- 1.4/2.8 GB 108.1 MB/s eta 0:00:13
#    -------------------- ------------------- 1.5/2.8 GB 107.9 MB/s eta 0:00:13
#    --------------------- ------------------ 1.5/2.8 GB 107.8 MB/s eta 0:00:13
#    --------------------- ------------------ 1.5/2.8 GB 107.7 MB/s eta 0:00:13
#    --------------------- ------------------ 1.5/2.8 GB 107.1 MB/s eta 0:00:12
#    ---------------------- ----------------- 1.6/2.8 GB 107.0 MB/s eta 0:00:12
#    ---------------------- ----------------- 1.6/2.8 GB 107.9 MB/s eta 0:00:12
#    ---------------------- ----------------- 1.6/2.8 GB 107.7 MB/s eta 0:00:12
#    ----------------------- ---------------- 1.6/2.8 GB 107.4 MB/s eta 0:00:12
#    ----------------------- ---------------- 1.6/2.8 GB 107.4 MB/s eta 0:00:11
#    ----------------------- ---------------- 1.7/2.8 GB 107.6 MB/s eta 0:00:11
#    ----------------------- ---------------- 1.7/2.8 GB 107.7 MB/s eta 0:00:11
#    ------------------------ --------------- 1.7/2.8 GB 107.6 MB/s eta 0:00:11
#    ------------------------ --------------- 1.7/2.8 GB 108.1 MB/s eta 0:00:11
#    ------------------------ --------------- 1.8/2.8 GB 108.7 MB/s eta 0:00:10
#    ------------------------- -------------- 1.8/2.8 GB 108.2 MB/s eta 0:00:10
#    ------------------------- -------------- 1.8/2.8 GB 108.3 MB/s eta 0:00:10
#    ------------------------- -------------- 1.8/2.8 GB 107.8 MB/s eta 0:00:10
#    -------------------------- ------------- 1.8/2.8 GB 107.8 MB/s eta 0:00:10
#    -------------------------- ------------- 1.9/2.8 GB 107.4 MB/s eta 0:00:09
#    -------------------------- ------------- 1.9/2.8 GB 107.4 MB/s eta 0:00:09
#    --------------------------- ------------ 1.9/2.8 GB 108.1 MB/s eta 0:00:09
#    --------------------------- ------------ 1.9/2.8 GB 107.4 MB/s eta 0:00:09
#    --------------------------- ------------ 2.0/2.8 GB 107.1 MB/s eta 0:00:09
#    ---------------------------- ----------- 2.0/2.8 GB 106.9 MB/s eta 0:00:08
#    ---------------------------- ----------- 2.0/2.8 GB 107.4 MB/s eta 0:00:08
#    ---------------------------- ----------- 2.0/2.8 GB 106.3 MB/s eta 0:00:08
#    ----------------------------- ---------- 2.0/2.8 GB 106.9 MB/s eta 0:00:08
#    ----------------------------- ---------- 2.1/2.8 GB 106.8 MB/s eta 0:00:07
#    ----------------------------- ---------- 2.1/2.8 GB 106.7 MB/s eta 0:00:07
#    ------------------------------ --------- 2.1/2.8 GB 107.5 MB/s eta 0:00:07
#    ------------------------------ --------- 2.1/2.8 GB 107.6 MB/s eta 0:00:07
#    ------------------------------ --------- 2.2/2.8 GB 107.6 MB/s eta 0:00:07
#    ------------------------------ --------- 2.2/2.8 GB 107.9 MB/s eta 0:00:06
#    ------------------------------- -------- 2.2/2.8 GB 107.7 MB/s eta 0:00:06
#    ------------------------------- -------- 2.2/2.8 GB 107.7 MB/s eta 0:00:06
#    ------------------------------- -------- 2.2/2.8 GB 107.7 MB/s eta 0:00:06
#    -------------------------------- ------- 2.3/2.8 GB 108.3 MB/s eta 0:00:06
#    -------------------------------- ------- 2.3/2.8 GB 107.9 MB/s eta 0:00:05
#    -------------------------------- ------- 2.3/2.8 GB 108.4 MB/s eta 0:00:05
#    --------------------------------- ------ 2.3/2.8 GB 107.8 MB/s eta 0:00:05
#    --------------------------------- ------ 2.4/2.8 GB 108.4 MB/s eta 0:00:05
#    --------------------------------- ------ 2.4/2.8 GB 108.8 MB/s eta 0:00:05
#    ---------------------------------- ----- 2.4/2.8 GB 109.3 MB/s eta 0:00:04
#    ---------------------------------- ----- 2.4/2.8 GB 109.1 MB/s eta 0:00:04
#    ---------------------------------- ----- 2.4/2.8 GB 110.1 MB/s eta 0:00:04
#    ----------------------------------- ---- 2.5/2.8 GB 109.9 MB/s eta 0:00:04
#    ----------------------------------- ---- 2.5/2.8 GB 109.8 MB/s eta 0:00:03
#    ----------------------------------- ---- 2.5/2.8 GB 110.3 MB/s eta 0:00:03
#    ------------------------------------ --- 2.5/2.8 GB 110.9 MB/s eta 0:00:03
#    ------------------------------------ --- 2.6/2.8 GB 110.3 MB/s eta 0:00:03
#    ------------------------------------ --- 2.6/2.8 GB 110.5 MB/s eta 0:00:03
#    ------------------------------------- -- 2.6/2.8 GB 111.4 MB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 GB 107.0 MB/s eta 0:00:02
#    ------------------------------------- -- 2.6/2.8 GB 101.6 MB/s eta 0:00:02
#    ------------------------------------- -- 2.7/2.8 GB 101.8 MB/s eta 0:00:02
#    -------------------------------------- - 2.7/2.8 GB 101.1 MB/s eta 0:00:02
#    -------------------------------------- - 2.7/2.8 GB 100.6 MB/s eta 0:00:02
#    -------------------------------------- - 2.7/2.8 GB 100.6 MB/s eta 0:00:01
#    -------------------------------------- - 2.7/2.8 GB 100.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 100.0 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 GB 99.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 GB 30.2 MB/s  0:00:32
# Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.7.1%2Bcu118-cp313-cp313-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    --------------- ------------------------ 1.6/4.1 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 9.5 MB/s  0:00:00
# Downloading https://download.pytorch.org/whl/pillow-11.3.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 7.0/7.0 MB 78.1 MB/s  0:00:00
# Installing collected packages: pillow, torch, torchvision, torchaudio
#
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#    ---------------------------------------- 0/4 [pillow]
#   Attempting uninstall: torch
#    ---------------------------------------- 0/4 [pillow]
#     Found existing installation: torch 2.9.0
#    ---------------------------------------- 0/4 [pillow]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#     Uninstalling torch-2.9.0:
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#       Successfully uninstalled torch-2.9.0
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ---------------------------------------- 4/4 [torchaudio]
#
# Successfully installed pillow-11.3.0 torch-2.7.1+cu118 torchaudio-2.7.1+cu118 torchvision-0.22.1+cu118
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ferhe\.conda\envs\ProyTesis2\Lib\site-packages\~orch'.
#   You can safely remove it manually.

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
print("Current CUDA device:", torch.cuda.current_device())
print("Device name:", torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# CUDA available: True
# CUDA device count: 1
# Current CUDA device: 0
# Device name: NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %% [markdown]
# ## Paso 2: Fine-tuning de BART con Hugging Face

# %%
# !pip uninstall transformers torch torchvision
# !pip install transformers==4.30.0 torch==2.0.1 torchvision==0.15.2 datasets

# %%
import torch
import os
os.environ["TRANSFORMERS_NO_TF"] = "1"

from transformers import BartTokenizer, BartForConditionalGeneration, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset

# 1. Cargar tokenizer y modelo preentrenado
model_name = "facebook/bart-base"
tokenizer = BartTokenizer.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name)

# Mover modelo a GPU si está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# 2. Cargar dataset desde el CSV generado
dataset = load_dataset("csv", data_files={"train": "corpus_trad.csv"}, split="train")

# 3. Preprocesamiento: tokenizar entradas y salidas
def preprocess(example):
    inputs = tokenizer(example["source"], max_length=128, truncation=True, padding="max_length")
    targets = tokenizer(example["target"], max_length=128, truncation=True, padding="max_length")
    inputs["labels"] = targets["input_ids"]
    return inputs

tokenized_dataset = dataset.map(preprocess, remove_columns=dataset.column_names)

# 4. Definir parámetros de entrenamiento
training_args = Seq2SeqTrainingArguments(
    output_dir="./bart_traducido",
    learning_rate=5e-5,
    per_device_train_batch_size=8,
    num_train_epochs=50,
    weight_decay=0.01,
    save_total_limit=1,
    predict_with_generate=True,
)

# 5. Crear trainer
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    tokenizer=tokenizer,
)

# 6. Entrenar
trainer.train()


## Guardar el modelo entrenado
# Después de trainer.train()
trainer.save_model("./bart_traducido_final")
tokenizer.save_pretrained("./bart_traducido_final")
# Out:
# C:\Users\ferhe\AppData\Local\Temp\ipykernel_42500\3777833169.py:41: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#     <div>
#
#       <progress value='12650' max='12650' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12650/12650 1:30:40, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.032000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.303700</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.233800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.176000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.129300</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.094600</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.068600</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.049800</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.038300</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.029800</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.023300</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.019800</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.016800</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.014100</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.011500</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.010100</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.009200</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.007900</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.007100</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.006100</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.005800</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.005300</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.003900</td>
#     </tr>
#   </tbody>
# </table><p>
# C:\Users\ferhe\.conda\envs\ProyTesis2\Lib\site-packages\transformers\modeling_utils.py:3918: UserWarning: Moving the following attributes in the config to the generation config: {'early_stopping': True, 'num_beams': 4, 'no_repeat_ngram_size': 3, 'forced_bos_token_id': 0}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# ('./bart_traducido_final\\tokenizer_config.json',
#  './bart_traducido_final\\special_tokens_map.json',
#  './bart_traducido_final\\vocab.json',
#  './bart_traducido_final\\merges.txt',
#  './bart_traducido_final\\added_tokens.json')

# %%
## Luego para cargar
#from transformers import BartTokenizer, BartForConditionalGeneration

#model_path = "D:/Jose/UNI\Maestria IA\Cursos\03_Tercer_ciclo\03_Proyecto_Tesis\Proyecto\Modelo\Local/bart_traducido_final"

#tokenizer = BartTokenizer.from_pretrained(model_path)
#model = BartForConditionalGeneration.from_pretrained(model_path)
